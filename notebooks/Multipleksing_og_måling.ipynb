# %% [markdown]
# # Multipleksing

# %%
import dwfpy as dwf

print(f"DWF Version: {dwf.Application.get_version()}")

with dwf.Device() as device:
    print(f"Found device: {device.name} ({device.serial_number})")

    pattern = device.digital_output

    print("Generating 1ms pulse...")

    # CH1: low when not running, initialize high on start
    pattern[0].setup(idle_state="low", initial_state="high", low_counter=0, high_counter=0)

    # 1ms run, once
    pattern.setup(run_length=1e-3, repeat_count=1, start=True)

    input("Press Enter key to exit.")
# Out:
# DWF Version: 3.24.4
# ---------------------------------------------------------------------------
# DeviceNotFound                            Traceback (most recent call last)
# Cell In[3], line 7
#       3 import dwfpy as dwf
#       5 print(f"DWF Version: {dwf.Application.get_version()}")
# ----> 7 with dwf.Device() as device:
#       8     print(f"Found device: {device.name} ({device.serial_number})")
#      10     pattern = device.digital_output
#
# File ~/.local/lib/python3.14/site-packages/dwfpy/device.py:78, in DeviceBase.__enter__(self)
#      77 def __enter__(self):
# ---> 78     self.open()
#      79     return self
#
# File ~/.local/lib/python3.14/site-packages/dwfpy/device.py:221, in DeviceBase.open(self)
#     218     if devices > 0:
#     219         raise DeviceNotFound(f"No devices match the filter {self._friendly_filter_spec()}")
# --> 221     raise DeviceNotFound("Device not found")
#     223 if not self._device_info.has_properties:
#     224     self._device_info.get_properties(device_index)
#
# DeviceNotFound: Device not found

# %% [markdown]
# # Måling
